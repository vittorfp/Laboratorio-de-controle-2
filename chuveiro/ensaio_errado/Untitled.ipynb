# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')

# %%
data = pd.read_csv('TESTE2.txt', sep=' ')

# %%
data[['PV']].plot(figsize=(20, 5))

# %%
data[['PV']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3569614f60>]],
#       dtype=object)
